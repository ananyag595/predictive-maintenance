# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("arnabbiswas1/microsoft-azure-predictive-maintenance")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\anany\.cache\kagglehub\datasets\arnabbiswas1\microsoft-azure-predictive-maintenance\3.archive...
# 100%|██████████| 31.0M/31.0M [00:03<00:00, 10.0MB/s]
# Extracting files...
# Path to dataset files: C:\Users\anany\.cache\kagglehub\datasets\arnabbiswas1\microsoft-azure-predictive-maintenance\versions\3
